# %%
# 들어온 이미지의 성별, 얼굴형, 컷/펌, 길이 정보 획득
gender = "여자"
face = "heart"
style = "cut"
length = "장"

# %%
# input : 성별(남자, 여자), 얼굴형(heart, oblong, round, square, oval), 컷/펌(cut, perm), 길이(장, 중, 단, 숏, 남자)
# output :path 이미지 저장 경로 딕셔너리 형태,  hair 딕셔너리 형태

def hairstyle_recom(gender, face, style, length) :
    if gender == "여자" :
        if face == "heart" : 
            if style=="cut" :
                if length == "장" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, heart, cut, 장발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "중" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, heart, cut, 중발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "단" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, heart, cut, 단발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "숏" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, heart, cut, 숏 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}

            elif style == "perm" : 
                if length == "장" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, heart, perm, 장발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "중" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, heart, perm, 중발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "단" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, heart, perm, 단발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "숏" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, heart, perm, 숏 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
      
        elif face == "oblong" :
            if style=="cut" :
                if length == "장" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, oblong, cut, 장발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "중" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, oblong, cut, 중발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "단" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, oblong, cut, 단발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "숏" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, oblong, cut, 숏 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}

            elif style == "perm" : 
                if length == "장" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, oblong, perm, 장발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "중" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, oblong, perm, 중발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "단" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, oblong, perm, 단발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "숏" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, oblong, perm, 숏 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
      
        elif face == "round" :
            if style=="cut" :
                if length == "장" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, round, cut, 장발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "중" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, round, cut, 중발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "단" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, round, cut, 단발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "숏" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, round, cut, 숏 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}

            elif style == "perm" : 
                if length == "장" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, round, perm, 장발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "중" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, round, perm, 중발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "단" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, round, perm, 단발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "숏" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, round, perm, 숏 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}

        elif face == "square" :
            if style=="cut" :
                if length == "장" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, square, cut, 장발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "중" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, square, cut, 중발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "단" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, square, cut, 단발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "숏" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, square, cut, 숏 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}

            elif style == "perm" : 
                if length == "장" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, square, perm, 장발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "중" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, square, perm, 중발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "단" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, square, perm, 단발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "숏" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, square, perm, 숏 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}

        else : # face = oval
            if style=="cut" :
                if length == "장" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, oval, cut, 장발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "중" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, oval, cut, 중발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "단" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, oval, cut, 단발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "숏" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, oval, cut, 숏 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}

            elif style == "perm" : 
                if length == "장" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, oval, perm, 장발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "중" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, oval, perm, 중발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "단" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, oval, perm, 단발 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
                elif length == "숏" :
                    hair = {"1":"원랭스", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 여자, oval, perm, 숏 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}

    else : # 성별 = 남자
        if face == "heart" : 
            if style=="cut" :
                if length == "남자" : # 남자  헤어 길이 분류는 '남자'만 있음
                    hair = {"1":"리프컷", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 남자, heart, cut, 남자 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
            elif style == "perm" : 
                if length == "남자" :
                    hair = {"1":"리젠트펌", "2":"바디펌", "3":"소트프투블럭댄디펌", "4":"쉐도우펌"} # 남자, heart, perm, 남자 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}

        elif face == "oblong" : 
            if style=="cut" :
                if length == "남자" :
                    hair = {"1":"리프컷", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 남자, oblong, cut, 남자 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
            elif style == "perm" : 
                if length == "남자" :
                    hair = {"1":"리젠트펌", "2":"바디펌", "3":"소트프투블럭댄디펌", "4":"쉐도우펌"} # 남자, oblong, perm, 남자 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}                            

        elif face == "round" : 
            if style=="cut" :
                if length == "남자" :
                    hair = {"1":"리프컷", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 남자, round, cut, 남자 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
            elif style == "perm" : 
                if length == "남자" :
                    hair = {"1":"리젠트펌", "2":"바디펌", "3":"소트프투블럭댄디펌", "4":"쉐도우펌"} # 남자, round, perm, 남자 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}   

        elif face == "square" : 
            if style=="cut" :
                if length == "남자" :
                    hair = {"1":"리프컷", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 남자, square, cut, 남자 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
            elif style == "perm" : 
                if length == "남자" :
                    hair = {"1":"리젠트펌", "2":"바디펌", "3":"소트프투블럭댄디펌", "4":"쉐도우펌"} # 남자, square, perm, 남자 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}

        elif face == "oval" : 
            if style=="cut" :
                if length == "남자" :
                    hair = {"1":"리프컷", "2":"플리츠컷", "3":"허쉬컷", "4":"숏컷"} # 남자, oval, cut, 남자 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}
            elif style == "perm" : 
                if length == "남자" :
                    hair = {"1":"리젠트펌", "2":"바디펌", "3":"소트프투블럭댄디펌", "4":"쉐도우펌"} # 남자, oval, perm, 남자 - 헤어스타일 4개 지정해서 넣어주기
                    path = {"1":"/path",
                            "2":"",
                            "3":"",
                            "4":""}   

    return path, hair

# %%
hairstyle_recom(gender, face, style, length)
# Out:
# ({'1': '/path', '2': '', '3': '', '4': ''},
#  {'1': '원랭스', '2': '플리츠컷', '3': '허쉬컷', '4': '숏컷'})
